# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
df = pd.read_csv('task2.csv')
df.head()
# Out:
#          x1        x2  y
# 0  0.996321  2.901429  1
# 1  3.855952  2.197317  1
# 2 -0.751851  1.311989  0
# 3 -1.535331  2.732352  1
# 4  2.808920  2.416145  1

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# 3d plot for 3 feature
fig = plt.figure()
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

ax.scatter(X.iloc[:, 0], X.iloc[:, 1], y, c=y, cmap='rainbow')
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('y')
# Out:
# Text(0.5, 0, 'y')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = MLPClassifier(alpha=0.5, max_iter=1000, random_state=42)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83       143
#            1       0.84      0.86      0.85       157
#
#     accuracy                           0.84       300
#    macro avg       0.84      0.84      0.84       300
# weighted avg       0.84      0.84      0.84       300

# %%
cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_).plot()

plt.title('alpha = 0.5')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()

# %%
clf2 = MLPClassifier(alpha=20, max_iter=1000, random_state=42)

clf2.fit(X_train, y_train)

y_pred2 = clf2.predict(X_test)

print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.63      0.73       143
#            1       0.73      0.92      0.82       157
#
#     accuracy                           0.78       300
#    macro avg       0.81      0.78      0.78       300
# weighted avg       0.80      0.78      0.78       300

# %%
cm = confusion_matrix(y_test, y_pred2)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_).plot()

plt.title('alpha = 20')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()
